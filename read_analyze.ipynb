# %%
import os
with open("analyze.txt", "r", encoding="utf-16") as f:
    content = f.read()
with open("analyze_utf8.txt", "w", encoding="utf-8") as f:
    f.write(content)
print("Converted successfully!")
print("First 500 characters of file:")
print(content[:500])
# Out:
# Converted successfully!
# First 500 characters of file:
# Analyzing finalproject...
#
#    info - The imported package 'flutter_image_compress' isn't a dependency of the importing package - lib\core\utils\image_processor.dart:6:8 - depend_on_referenced_packages
#   error - Target of URI doesn't exist: 'package:flutter_image_compress/flutter_image_compress.dart' - lib\core\utils\image_processor.dart:6:8 - uri_does_not_exist
#   error - Undefined name 'FlutterImageCompress' - lib\core\utils\image_processor.dart:17:28 - und
